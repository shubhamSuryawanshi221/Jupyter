# %%
pip install pandas

# %%
import pandas as pd

# %%
Pandas >> Python Data Analysis (phrase)
import pandas as pd

# %% [markdown]
# ## Two data structure in pandas

# %%
1. DataFrame: multiple rows and multiple columns
    2- Dimentional >>> rows and columns
2. series:
    1 -Dimentional >> only one column, we can have multiple rows.

# %% [markdown]
# ## Pandas Functions

# %%
1. df.columns
2. df.index
3. df.axes
4. df.dtypes
5. df.select_dtypes(include,exclude)
6. df.info()
7. df.describe()
8. df.shape

## Access Columns and Rows

1. df.iloc[row_index,col_index]
2. df.loc[row_lables,col_lables]
3. df[col_name]>> single colmn name20. np.append
4. df[[col1,col2,....colN]]>>> multiple col name
5. df[start_row_index,end_row_index] >>> :
    df[3:6]   >> 3,4,5 rows
6. df.head() >>> first N rows >> Def val is 5
7. df.tail() >>> lat N rows >> Def val is 5
8. pd.read_csv()
9. pd.read_excel()

# %% [markdown]
# ## Use Cases

# %%
1. Read csv,excel,json files
2. EDA Exploratory Data Analysis (50%)
3. Data Cleansing:
    Missing Values
    Outliers
4. Encoding:
    One hot encoding 
    Label Encoding
5. Feature Selection
6. Join Multiple tables

# %% [markdown]
# # How to create DataFrames

# %% [markdown]
# ## Examples of constructing DataFrames from different sources and data types

# %%
1. Reading csv,excel,json files
2. Array(1-D or 2-D array)
3. Dictionary
4. List
5. Tuples
6. Series

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## 1. array

# %%
array1=np.random.randint(10,20,size=(10,5))
array1
# Out:
# array([[11, 11, 16, 13, 13],
#        [12, 11, 10, 15, 16],
#        [10, 18, 17, 10, 13],
#        [12, 12, 14, 14, 13],
#        [15, 17, 16, 15, 15],
#        [16, 10, 15, 13, 18],
#        [11, 19, 16, 18, 18],
#        [16, 17, 15, 17, 12],
#        [11, 12, 14, 19, 17],
#        [10, 14, 19, 15, 10]])

# %%
df=pd.DataFrame(array1)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 2.list

# %%
list1=[1,23,43,456,7,43,8,4]
df1=pd.DataFrame(list1)
type(df1)
df1
# Out:
#      0
# 0    1
# 1   23
# 2   43
# 3  456
# 4    7
# 5   43
# 6    8
# 7    4

# %% [markdown]
# ## 3. by using tuple

# %%
t1=(1,2,3,4)
df2=pd.DataFrame(t1)
df2
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
## 4.by using dictionary

# %%
d3={"A":[2,3,4,5,6],"B":[10,20,30,40,50],"C":np.array([100,200,300,400,500]),"D":np.arange(300,305)}
d3
df3=pd.DataFrame(d3)
df3
# Out:
#    A   B    C    D
# 0  2  10  100  300
# 1  3  20  200  301
# 2  4  30  300  302
# 3  5  40  400  303
# 4  6  50  500  304

# %% [markdown]
# ## 5.Read csv file

# %%
#df=pd.read_csv(r"C:\Users\VISHNU KALE\Desktop\python july mid\python_27_pandas\movies_data.csv" )

df=pd.read_csv("movies_data.csv") #r"C:\Users\VISHNU KALE\Desktop\python july mid\python_27_pandas\movies_data.csv" 
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df11=pd.read_excel("Emp_Records.xlsx")
df11
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
## writing data

# %%
# to save dataframe to CSV
df11.to_csv("final_file.csv")

# %%
# to save dataframe to excel 
df11.to_excel("final_file.xlsx", sheet_name="name")

# %%
#append data into existing file
with pd.ExcelWriter("final_file.xlsx", mode="a") as writer:
    df11.to_excel(writer, sheet_name="newsheet")

# %%
# save df into json
df.to_json("file.json")

# %%
df11
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
#to get the list of all the columns we use this fucntion
df11.columns
# Out:
# Index(['Emp ID', 'First Name', 'Age in Yrs', 'Weight in Kgs', 'Age in Company',
#        'Salary', 'City'],
#       dtype='object')

# %%
#return list of row names (labels)
df11.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
#to get the both row labels and columns labels
df11.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['Emp ID', 'First Name', 'Age in Yrs', 'Weight in Kgs', 'Age in Company',
#         'Salary', 'City'],
#        dtype='object')]

# %%
df11.dtypes #
# Out:
# Emp ID              int64
# First Name         object
# Age in Yrs        float64
# Weight in Kgs       int64
# Age in Company    float64
# Salary              int64
# City               object
# dtype: object

# %%
df11.isna().sum() #missing values, 0,
# Out:
# Emp ID            0
# First Name        0
# Age in Yrs        0
# Weight in Kgs     0
# Age in Company    0
# Salary            0
# City              0
# dtype: int64

# %%
df11.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Emp ID          100 non-null    int64
#  1   First Name      100 non-null    object
#  2   Age in Yrs      100 non-null    float64
#  3   Weight in Kgs   100 non-null    int64
#  4   Age in Company  100 non-null    float64
#  5   Salary          100 non-null    int64
#  6   City            100 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 5.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
# ...

# %%
df11.select_dtypes(include=float)
# Out:
#     Age in Yrs  Age in Company
# 0        36.36           13.68
# 1        47.02            9.01
# 2        54.15            0.98
# 3        39.67           18.30
# 4        40.31            4.01
# ..         ...             ...
# 95       22.82            1.05
# 96       32.61            5.93
# 97       52.66           28.53
# 98       29.60            6.99
# 99       38.38            2.26
#
# [100 rows x 2 columns]

# %%
df11.select_dtypes(exclude=float)
# Out:
#     Emp ID First Name  Weight in Kgs  Salary          City
# 0   677509       Lois             60  168251        Denver
# 1   940761     Brenda             60   51063     Stonewall
# 2   428945        Joe             68   50155  Michigantown
# 3   408351      Diane             51  180294      Hydetown
# 4   193819   Benjamin             58  117642       Fremont
# ..     ...        ...            ...     ...           ...
# 95  639892       Jose             89  129774        Biloxi
# 96  704709     Harold             77  156194  Carol Stream
# 97  461593     Nicole             60   95673       Detroit
# 98  392491    Theresa             57   51015      Mc Grath
# 99  495141      Tammy             55   93650          Alma
#
# [100 rows x 5 columns]

# %%
# create dataframe by using excel file

# %%
#to get statistical summary of dataframe

df11.describe()
# Out:
#              Emp ID  Age in Yrs  Weight in Kgs  Age in Company         Salary
# count     100.00000  100.000000     100.000000      100.000000     100.000000
# mean   547652.10000   39.238700      58.080000        8.978400  119738.090000
# std    257664.16679   12.066252      12.294106        8.657358   46185.278194
# min    134841.00000   21.100000      40.000000        0.020000   42005.000000
# 25%    328643.75000   28.177500      50.000000        2.152500   83979.750000
# 50%    497414.00000   37.595000      56.000000        6.435000  118049.500000
# 75%    766040.00000   49.900000      61.250000       13.762500  162509.250000
# max    979607.00000   59.470000      90.000000       34.520000  197537.000000

# %%
df11[["Age in Yrs"]]
# Out:
#     Age in Yrs
# 0        36.36
# 1        47.02
# 2        54.15
# 3        39.67
# 4        40.31
# ..         ...
# 95       22.82
# 96       32.61
# 97       52.66
# 98       29.60
# 99       38.38
#
# [100 rows x 1 columns]

# %%
df11[["Emp ID","Salary"]]
# Out:
#     Emp ID  Salary
# 0   677509  168251
# 1   940761   51063
# 2   428945   50155
# 3   408351  180294
# 4   193819  117642
# ..     ...     ...
# 95  639892  129774
# 96  704709  156194
# 97  461593   95673
# 98  392491   51015
# 99  495141   93650
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Access rows and columns

# %%
df11
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# ##  1. df.iloc(row_index, column_index)

# %%
# 1. df.iloc(row_index, column_index)
df11.iloc[:,:]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df11.iloc[2:6, 0:5]
# Out:
#    Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company
# 2  428945        Joe       54.15             68            0.98
# 3  408351      Diane       39.67             51           18.30
# 4  193819   Benjamin       40.31             58            4.01
# 5  499687    Patrick       34.86             58           12.02

# %% [markdown]
# ## df.loc[row_labels, column_labels]

# %%
df11.loc[2:10]
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# 5   499687    Patrick       34.86             58           12.02   72305
# 6   539712      Nancy       22.14             50            0.87   98189
# 7   380086      Carol       59.12             40           34.52   60918
# 8   477616    Frances       58.18             42           23.27  121587
# 9   162402      Diana       29.73             60            3.44   43010
# 10  231469      Ralph       42.50             80            8.29  118457
#
#               City
# 2     Michigantown
# 3         Hydetown
# 4          Fremont
# 5        Macksburg
# 6          Atlanta
# 7      Blanchester
# 8          Delmita
# 9   Eureka Springs
# 10         Sabetha

# %%
df11.loc[2:10, "First Name":"Salary"]
# Out:
#    First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary
# 2         Joe       54.15             68            0.98   50155
# 3       Diane       39.67             51           18.30  180294
# 4    Benjamin       40.31             58            4.01  117642
# 5     Patrick       34.86             58           12.02   72305
# 6       Nancy       22.14             50            0.87   98189
# 7       Carol       59.12             40           34.52   60918
# 8     Frances       58.18             42           23.27  121587
# 9       Diana       29.73             60            3.44   43010
# 10      Ralph       42.50             80            8.29  118457

# %% [markdown]
# ## Functions for data inspection

# %%
df11.head()
df11.head(15)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36             60           13.68  168251
# 1   940761     Brenda       47.02             60            9.01   51063
# 2   428945        Joe       54.15             68            0.98   50155
# 3   408351      Diane       39.67             51           18.30  180294
# 4   193819   Benjamin       40.31             58            4.01  117642
# 5   499687    Patrick       34.86             58           12.02   72305
# 6   539712      Nancy       22.14             50            0.87   98189
# 7   380086      Carol       59.12             40           34.52   60918
# 8   477616    Frances       58.18             42           23.27  121587
# 9   162402      Diana       29.73             60            3.44   43010
# 10  231469      Ralph       42.50             80            8.29  118457
# 11  153989       Jack       22.21             61            0.56   82965
# ...

# %%
df11.tail(10)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 90  185032     Eugene       37.84             59            2.64  122950
# 91  867084    Deborah       39.77             54           15.41   52767
# 92  969964     Janice       37.57             56            0.93  147641
# 93  158666    Rebecca       56.00             55           34.32  160043
# 94  489424    Phillip       39.43             82            1.56  181774
# 95  639892       Jose       22.82             89            1.05  129774
# 96  704709     Harold       32.61             77            5.93  156194
# 97  461593     Nicole       52.66             60           28.53   95673
# 98  392491    Theresa       29.60             57            6.99   51015
# 99  495141      Tammy       38.38             55            2.26   93650
#
#                        City
# 90                   Racine
# 91                  Atqasuk
# 92  Whiteman Air Force Base
# 93             Independence
# ...

# %%
#shape of dataframe 
df11.shape
# Out:
# (100, 7)

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df3=pd.read_csv("titanic.csv")
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3.shape[1]
# Out:
# 12

# %%
df3.isna().sum() #sum of null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# unique 


df3["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df3["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df3["Gender"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#unique >>> number of unique values

df3["Gender"].nunique()
# Out:
# 2

# %%
df3["Embarked"].nunique()
# Out:
# 3

# %%
# value_counts()>>> unique values and its count

df3["Gender"].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df3["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ## pd.crosstab

# %%
>> It counts the frequency of combination between two or more columns
>> summarize categorical data

# %%
pd.crosstab(df3["Survived"],df3["Gender"])
# Out:
# Gender    female  male
# Survived
# 0             81   466
# 1            233   111

# %%
C = Cherbourg, Q = Queenstown, S = Southampton

# %%
pd.crosstab([df3["Pclass"],df3["Embarked"]],[df3["Gender"], df3["Survived"]])
# Out:
# Gender          female     male
# Survived             0   1    0   1
# Pclass Embarked
# 1      C             1  42   25  17
#        Q             0   1    1   0
#        S             2  46   51  28
# 2      C             0   7    8   2
#        Q             0   2    1   0
#        S             6  61   82  15
# 3      C             8  15   33  10
#        Q             9  24   35   4
#        S            55  33  230  35

# %% [markdown]
# ## how to load the existing datasets from seaborn library

# %%
## how to load the existing datasets from seaborn library
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset("diamonds")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df1=sns.load_dataset('planets')
df1
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]
